# %% [markdown]
# ## Fazendo a conexão com o banco de dados do MongoDB

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from dotenv import load_dotenv
import os

load_dotenv()
db_passowrd = os.getenv('passorwd_mongodb')

uri = f"mongodb+srv://lucashidini:{db_passowrd}@cluster-pipeline.2qeq7uu.mongodb.net/?retryWrites=true&w=majority&appName=Cluster-Pipeline"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['db_produtos']
collection  = db['prdoutos']

# %%
client.list_database_names()
# Out:
# ['sample_mflix', 'admin', 'local']

# %%
product = {
    'produto': 'computador',
    'quantidade': 77
}
collection.insert_one(product)
# Out:
# InsertOneResult(ObjectId('68b33c2dab21d22bced40f2c'), acknowledged=True)

# %%
client.list_database_names()
# Out:
# ['db_produtos', 'sample_mflix', 'admin', 'local']

# %%
import requests

response = requests.get('https://labdados.com/produtos')
response.json()
# Out:
# [{'Produto': 'Modelagem preditiva',
#   'Categoria do Produto': 'livros',
#   'Preço': 92.45,
#   'Frete': 5.6096965236,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Iniciando em programação',
#   'Categoria do Produto': 'livros',
#   'Preço': 43.84,
#   'Frete': 0.0,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Pandeiro',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 87.18,
#   'Frete': 2.2265117938,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 4,
# ...

# %%
len(response.json())
# Out:
# 9435

# %%
collection.insert_many(response.json())
# Out:
# InsertManyResult([ObjectId('68b3490aab21d22bced40f2d'), ObjectId('68b3490aab21d22bced40f2e'), ObjectId('68b3490aab21d22bced40f2f'), ObjectId('68b3490aab21d22bced40f30'), ObjectId('68b3490aab21d22bced40f31'), ObjectId('68b3490aab21d22bced40f32'), ObjectId('68b3490aab21d22bced40f33'), ObjectId('68b3490aab21d22bced40f34'), ObjectId('68b3490aab21d22bced40f35'), ObjectId('68b3490aab21d22bced40f36'), ObjectId('68b3490aab21d22bced40f37'), ObjectId('68b3490aab21d22bced40f38'), ObjectId('68b3490aab21d22bced40f39'), ObjectId('68b3490aab21d22bced40f3a'), ObjectId('68b3490aab21d22bced40f3b'), ObjectId('68b3490aab21d22bced40f3c'), ObjectId('68b3490aab21d22bced40f3d'), ObjectId('68b3490aab21d22bced40f3e'), ObjectId('68b3490aab21d22bced40f3f'), ObjectId('68b3490aab21d22bced40f40'), ObjectId('68b3490aab21d22bced40f41'), ObjectId('68b3490aab21d22bced40f42'), ObjectId('68b3490aab21d22bced40f43'), ObjectId('68b3490aab21d22bced40f44'), ObjectId('68b3490aab21d22bced40f45'), ObjectId('68b3490aab21d22bced4
# ...

# %%
collection.count_documents({})
# Out:
# 9436

# %%
id_remover = collection.find_one()['_id']

# %%
collection.delete_one({'_id': id_remover})
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000054'), 'opTime': {'ts': Timestamp(1756580331, 1), 't': 84}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1756580331, 1), 'signature': {'hash': b'?$\xd7I\x1d#Z&s\x86\x98\x1e\xc7\xca\xe2\x106j\xed\x0e', 'keyId': 7512207205853036554}}, 'operationTime': Timestamp(1756580331, 1)}, acknowledged=True)

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('68b3490aab21d22bced40f2d'),
#  'Produto': 'Modelagem preditiva',
#  'Categoria do Produto': 'livros',
#  'Preço': 92.45,
#  'Frete': 5.6096965236,
#  'Data da Compra': '01/01/2020',
#  'Vendedor': 'Thiago Silva',
#  'Local da compra': 'BA',
#  'Avaliação da compra': 1,
#  'Tipo de pagamento': 'cartao_credito',
#  'Quantidade de parcelas': 3,
#  'lat': -13.29,
#  'lon': -41.71}

# %%
client.close()
